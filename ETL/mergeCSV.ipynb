# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('../data/raw/vietnamese_tiki_products_backpacks_suitcases.csv')
df1.head()
# Out:
#    Unnamed: 0         id                                               name  \
# 0           0  179731375  Balo nữ da dầy thời trang unisex màu sắc tươi ...
# 1           1  249221065            Ví da đựng thẻ ngân hàng (7 màu) - 9205
# 2           2  102862196   Balo nam nữ thời trang họa tiết bò sữa kiểu m...
# 3           3  115740385  Vải nhũ bóng simili chống thấm may túi ví balo...
# 4           4  102862375   Combo balo vừa a4 và túi tote thời trang kiểu...
#
#                                          description  original_price  price  \
# 0    Balo nữ da dầy thời trang unisex màu sắc tươ...           14250  14250
# 1                                                ...           10260  10260
# 2         Balo họa tiết bò sữa thời trang cho nam...           19999  19999
# 3         _ Vải nhũ bóng siêu xinh và cực kì xịn ...           30000  30000
# 4         BALO THỜI TRANG - BALO ĐẸP – BALO HỌC S...           29000  29000
#
# ...

# %%
df2 = pd.read_csv('../data/raw/vietnamese_tiki_products_backpacks_suitcases.csv')
df2.head()
# Out:
#    Unnamed: 0         id                                               name  \
# 0           0  179731375  Balo nữ da dầy thời trang unisex màu sắc tươi ...
# 1           1  249221065            Ví da đựng thẻ ngân hàng (7 màu) - 9205
# 2           2  102862196   Balo nam nữ thời trang họa tiết bò sữa kiểu m...
# 3           3  115740385  Vải nhũ bóng simili chống thấm may túi ví balo...
# 4           4  102862375   Combo balo vừa a4 và túi tote thời trang kiểu...
#
#                                          description  original_price  price  \
# 0    Balo nữ da dầy thời trang unisex màu sắc tươ...           14250  14250
# 1                                                ...           10260  10260
# 2         Balo họa tiết bò sữa thời trang cho nam...           19999  19999
# 3         _ Vải nhũ bóng siêu xinh và cực kì xịn ...           30000  30000
# 4         BALO THỜI TRANG - BALO ĐẸP – BALO HỌC S...           29000  29000
#
# ...

# %%
df3 = pd.read_csv('../data/raw/vietnamese_tiki_products_men_bags.csv')
df3.head()
# Out:
#    Unnamed: 0         id                                               name  \
# 0           0  179731388  Túi Đeo Chéo Nam Nhỏ Gọn Tiện Lợi Phong Cách H...
# 1           1  207737218  Túi đeo chéo mini phối màu xíu xinh phong cách...
# 2           2  179731359  Túi đeo chéo mini nam nữ thời trang nhỏ gọn bỏ...
# 3           3  102862656   Túi Đeo Chéo Hà Mã thời trang hai ngăn siêu r...
# 4           4  198227440  Tất Nam Nữ Trơn Cổ Ngắn Vớ Nam Thời Trang Cao ...
#
#                                          description  original_price  price  \
# 0    Túi Đeo Chéo Nam Nhỏ Gọn Tiện Lợi Phong Cách...           15000  15000
# 1  Chào mừng bạn đến với cửa hàng của tôiSản phẩm...            9000   9000
# 2    Chất liệu : PVC cao cấp chống thấm nước, bảo...           15000  15000
# 3         ‭ ⇒ Màu sắc : Đen   ⇒ Kích thước: gọn g...            8500   8500
# 4  - Tất - Vớ là một loại vật dụng không thể thiế...            1350   1350
#
# ...

# %%
df4 = pd.read_csv('../data/raw/vietnamese_tiki_products_men_shoes.csv')
df4.head()
# Out:
#    Unnamed: 0         id                                               name  \
# 0           0  103682599  D4 Dép Tổ Ong Đi Mưa, Đi Trong Nhà Nam Nữ Chất...
# 1           1  176818958  DÉP TỔ ONG ĐEN NHỰA CAO SU DẺO LOẠI ĐẸP ĐỦ SIZ...
# 2           2  119214657                   dép tổ ong huyền thoại full size
# 3           3  164789853          Dép tổ ong đi trong nhà dày mỏng các loại
# 4           4  208440729  Dép xốp QUAI NGANG đi trong nhà/Khách sạn/Spa,...
#
#                                          description  original_price  price  \
# 0         Dép Tổ Ong Đi Mưa, Đi Trong Nhà Nam Nữ ...            9900   9900
# 1         LƯU Ý : KHÁCH MUA TỪ 5 ĐÔI TRỞ LÊN SHOP...           10000  10000
# 2         Dép Làm Chất liệu cao su tổng hợp giúp ...            9900   9900
# 3         THÔNG TIN SẢN PHẨM   DÉP TỔ ONG CÁC LOẠ...           24999  24999
# 4         Dép xốp quai ngang, đi trong nhà/Khách ...           14200  14200
#
# ...

# %%
df5 = pd.read_csv('../data/raw/vietnamese_tiki_products_women_bags.csv')
df5.head()
# Out:
#    Unnamed: 0         id                                               name  \
# 0           0  259480018  Túi Xách Nữ Da Mềm Thời Trang Du Lịch Phong Cá...
# 1           1  260801038  Túi Xách Đeo Vai  Kẹp Nách Đi Học Đi Chơi Thời...
# 2           2  260800735  Túi Đeo Chéo Nữ Thời Trang Đi Làm Dự Tiệc Phon...
# 3           3  260799998  Túi Đeo Chéo Nữ Chất Da Xịn Túi Du Lịch Đi Làm...
# 4           4  259481422  Túi Xách Đeo Vai Túi Cầm Tay Nữ Đi Chơi Dự Tiệ...
#
#                                          description  original_price  price  \
# 0         Mô Tả Sản Phẩm:Túi Xách Nữ Da Mềm Thời ...           85000  85000
# 1         Mô Tả Sản Phẩm:Túi Xách Đeo Vai Kẹp Nác...           89000  89000
# 2         Mô Tả Sản Phẩm:Túi Đeo Chéo Nữ Thời Tra...           89000  89000
# 3         SHOP LOTIBA   Mô Tả Sản Phẩm:Túi Đeo Ch...           89000  89000
# 4         Mô Tả Sản Phẩm:Túi Xách Đeo Vai Túi Cầm...           89000  89000
#
# ...

# %%
df6 = pd.read_csv('../data/raw/vietnamese_tiki_products_women_shoes.csv')
df6.head()
# Out:
#    Unnamed: 0         id                                               name  \
# 0           0  252071637  Hộp dép, hộp đựng dép hm - màu cam kich thước ...
# 1           1  208439152  Dép xốp quai ngang đi trong nhà- dép xốp khách...
# 2           2  105883794                             dép tổ ông huyền thoại
# 3           3  252864898                      Sen guốc trơn lá lớn_Ảnh thật
# 4           4  252865522                                  Cây guốc sao trơn
#
#                                          description  original_price  price  \
# 0         Hộp dép, hộp đựng dép hm - màu cam, kíc...            3000   3000
# 1    Dép xốp quai ngang, đi trong nhà/Khách sạn/Đ...           14200  14200
# 2  Thiết kế đặc biệtChống trơn trượtKhông ngậm nư...            9900   9900
# 3         Chào bạn, cảm ơn bạn đã ghé thăm shop ạ...           15000  15000
# 4         Cây hawothia guốc sao trơn cây đang con...           13000  13000
#
# ...

# %%
df_merged = pd.concat([df1, df2, df3, df4, df5, df6], ignore_index=True)

# Xuất ra file CSV
df_merged.to_csv("../data/raw/merged_data.csv", index=False)
